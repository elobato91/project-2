# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv

# %%
url = "https://www.digitaltrends.com/mobile/5g-availability-map/"
stateabb = ['AZ','NM']

# %%
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
results = soup.find_all('div', class_='b-page')

# %%
states = []
for result in results:
    try:
        state_list = result.ul.text
        states_list = result.ul.text
        if (state and state_list):
            print(state_list)
        states.append((state_list))
    except AttributeError as e:
        print(e)
# Out:
# Birmingham, AL
# Huntsville, AL
# Gila County, AZ
# Phoenix, AZ
# Bakersfield, CA
# Los Angeles, CA
# Madera County, CA
# Menlo Park, CA
# Modesto, CA
# Mono County, CA
# Oakland, CA
# Oxnard, CA
# Redwood City, CA
# San Bruno, CA
# San Diego, CA
# San Francisco, CA
# San Jose, CA
# San Luis Obispo, CA
# Santa Barbara, CA
# Santa Cruz, CA
# Santa Rosa, CA
# Vallejo, CA
# West Hollywood, CA
# Denver, CO
# New Haven, CT
# Bridgeport, CT
# Hartford, CT
# Washington D.C.
# Kent County, DE
# Wilmington, DE
# Jacksonville, FL
# Miami, FL
# Miami Gardens, FL
# Orlando, FL
# Albany, GA
# Athens, GA
# Atlanta, GA
# Chattooga County, GA
# Hancock County, GA
# Liberty, GA
# Macon, GA
# Whitfield County, GA
# Worth County, GA
# Washington County, IL
# Brown County, IN
# Indianapolis, IN
# Topeka, KS
# Wichita, KS
# Lexington-Fayette, KY
# Louisville, KY
# New Orleans, LA
# Boston, MA
# New Bedford, MA
# Worcester, MA
# Baltimore, MD
# Frederick, MD
# Ocean City, MD
# Detroit, MI
# ...
